# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print (plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn')

# %%
pd.read_csv(r'C:\Users\kuti\Desktop\MY HTML JOURNEY\My Anaconda\Cancelled_Diverted_2023.csv')
df = pd.read_csv(r'C:\Users\kuti\Desktop\MY HTML JOURNEY\My Anaconda\Cancelled_Diverted_2023.csv')

# %%
df.drop_duplicates()
df
# Out:
#         FlightDate  Day_Of_Week          Airline Tail_Number  Cancelled  \
# 0       2023-01-25            3     Endeavor Air      N691CA        1.0
# 1       2023-01-03            2     Endeavor Air      N937XJ        1.0
# 2       2023-01-03            2     Endeavor Air      N937XJ        1.0
# 3       2023-01-11            3     Endeavor Air      N926XJ        1.0
# 4       2023-01-25            3     Endeavor Air      N335PQ        0.0
# ...            ...          ...              ...         ...        ...
# 104483  2023-12-29            5  JetBlue Airways      N206JB        1.0
# 104484  2023-12-29            5  JetBlue Airways      N636JB        1.0
# 104485  2023-12-29            5  JetBlue Airways      N661JB        0.0
# 104486  2023-12-29            5  JetBlue Airways      N216JB        1.0
# 104487  2023-12-31            7  JetBlue Airways      N952JB        0.0
#
#         Diverted Dep_Airport         Dep_CityName DepTime_label  Dep_Delay  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104488 entries, 0 to 104487
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   FlightDate          104488 non-null  object
#  1   Day_Of_Week         104488 non-null  int64
#  2   Airline             104488 non-null  object
#  3   Tail_Number         104488 non-null  object
#  4   Cancelled           104488 non-null  float64
#  5   Diverted            104488 non-null  float64
#  6   Dep_Airport         104488 non-null  object
#  7   Dep_CityName        104488 non-null  object
#  8   DepTime_label       104488 non-null  object
#  9   Dep_Delay           104488 non-null  float64
#  10  Dep_Delay_Tag       104488 non-null  int64
#  11  Dep_Delay_Type      104488 non-null  object
#  12  Arr_Airport         104488 non-null  object
#  13  Arr_CityName        104488 non-null  object
#  14  Arr_Delay           104488 non-null  float64
# ...

# %%
df.drop(columns = ['Delay_Carrier','Delay_Weather', 'Delay_NAS', 'Delay_Security', 'Delay_LastAircraft', 'Dep_Delay_Tag', 'Flight_Duration', 'Dep_Delay', 'Arr_Delay'])
df = df.drop(columns = ['Delay_Carrier','Delay_Weather', 'Delay_NAS', 'Delay_Security', 'Delay_LastAircraft', 'Dep_Delay_Tag', 'Flight_Duration', 'Dep_Delay', 'Arr_Delay'])
df
# Out:
#         FlightDate  Day_Of_Week          Airline Tail_Number  Cancelled  \
# 0       2023-01-25            3     Endeavor Air      N691CA        1.0
# 1       2023-01-03            2     Endeavor Air      N937XJ        1.0
# 2       2023-01-03            2     Endeavor Air      N937XJ        1.0
# 3       2023-01-11            3     Endeavor Air      N926XJ        1.0
# 4       2023-01-25            3     Endeavor Air      N335PQ        0.0
# ...            ...          ...              ...         ...        ...
# 104483  2023-12-29            5  JetBlue Airways      N206JB        1.0
# 104484  2023-12-29            5  JetBlue Airways      N636JB        1.0
# 104485  2023-12-29            5  JetBlue Airways      N661JB        0.0
# 104486  2023-12-29            5  JetBlue Airways      N216JB        1.0
# 104487  2023-12-31            7  JetBlue Airways      N952JB        0.0
#
#         Diverted Dep_Airport         Dep_CityName DepTime_label  \
# ...

# %%
df['Day_Of_Week'].replace({1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'})
df['Day_Of_Week'] = df['Day_Of_Week'].replace({1: 'Monday', 2: 'Tuesday', 3: 'Wednesday', 4: 'Thursday', 5: 'Friday', 6: 'Saturday', 7: 'Sunday'})
df
# Out:
#         FlightDate Day_Of_Week          Airline Tail_Number  Cancelled  \
# 0       2023-01-25   Wednesday     Endeavor Air      N691CA        1.0
# 1       2023-01-03     Tuesday     Endeavor Air      N937XJ        1.0
# 2       2023-01-03     Tuesday     Endeavor Air      N937XJ        1.0
# 3       2023-01-11   Wednesday     Endeavor Air      N926XJ        1.0
# 4       2023-01-25   Wednesday     Endeavor Air      N335PQ        0.0
# ...            ...         ...              ...         ...        ...
# 104483  2023-12-29      Friday  JetBlue Airways      N206JB        1.0
# 104484  2023-12-29      Friday  JetBlue Airways      N636JB        1.0
# 104485  2023-12-29      Friday  JetBlue Airways      N661JB        0.0
# 104486  2023-12-29      Friday  JetBlue Airways      N216JB        1.0
# 104487  2023-12-31      Sunday  JetBlue Airways      N952JB        0.0
#
#         Diverted Dep_Airport         Dep_CityName DepTime_label  \
# ...

# %%
df = df.set_index('Airline')
df
# Out:
#                  FlightDate Day_Of_Week Tail_Number  Cancelled  Diverted  \
# Airline
# Endeavor Air     2023-01-25   Wednesday      N691CA        1.0       0.0
# Endeavor Air     2023-01-03     Tuesday      N937XJ        1.0       0.0
# Endeavor Air     2023-01-03     Tuesday      N937XJ        1.0       0.0
# Endeavor Air     2023-01-11   Wednesday      N926XJ        1.0       0.0
# Endeavor Air     2023-01-25   Wednesday      N335PQ        0.0       1.0
# ...                     ...         ...         ...        ...       ...
# JetBlue Airways  2023-12-29      Friday      N206JB        1.0       0.0
# JetBlue Airways  2023-12-29      Friday      N636JB        1.0       0.0
# JetBlue Airways  2023-12-29      Friday      N661JB        0.0       1.0
# JetBlue Airways  2023-12-29      Friday      N216JB        1.0       0.0
# JetBlue Airways  2023-12-31      Sunday      N952JB        0.0       1.0
#
#                 Dep_Airport         Dep_CityName DepTime_label  \
# Airline
# ...

# %%
df2 = df.groupby('Airline').sum().sort_values(by = 'Cancelled', ascending = False)
df2
# Out:
#                               Cancelled  Diverted
# Airline
# Southwest Airlines Co.          14325.0    2902.0
# United Air Lines Inc.           10270.0    1910.0
# Delta Air Lines Inc             10016.0    2039.0
# American Airlines Inc.           9978.0    2495.0
# Skywest Airlines Inc.            8252.0    2050.0
# Republic Airways                 8163.0     622.0
# JetBlue Airways                  5763.0    1174.0
# Spirit Air Lines                 4479.0     547.0
# Endeavor Air                     4242.0     373.0
# Frontier Airlines Inc.           3774.0     309.0
# PSA Airlines                     2571.0     501.0
# American Eagle Airlines Inc.     2291.0     502.0
# Alaska Airlines Inc.             1977.0     724.0
# Hawaiian Airlines Inc.           1053.0      72.0
# Allegiant Air                     782.0     332.0

# %%
df2.plot(kind = 'bar', figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='Airline'>

# %%
df2.plot(kind = 'bar', subplots = True, figsize=(15, 5))
# Out:
# array([<AxesSubplot:title={'center':'Cancelled'}, xlabel='Airline'>,
#        <AxesSubplot:title={'center':'Diverted'}, xlabel='Airline'>],
#       dtype=object)

# %%
df
# Out:
#                  FlightDate Day_Of_Week Tail_Number  Cancelled  Diverted  \
# Airline
# Endeavor Air     2023-01-25   Wednesday      N691CA        1.0       0.0
# Endeavor Air     2023-01-03     Tuesday      N937XJ        1.0       0.0
# Endeavor Air     2023-01-03     Tuesday      N937XJ        1.0       0.0
# Endeavor Air     2023-01-11   Wednesday      N926XJ        1.0       0.0
# Endeavor Air     2023-01-25   Wednesday      N335PQ        0.0       1.0
# ...                     ...         ...         ...        ...       ...
# JetBlue Airways  2023-12-29      Friday      N206JB        1.0       0.0
# JetBlue Airways  2023-12-29      Friday      N636JB        1.0       0.0
# JetBlue Airways  2023-12-29      Friday      N661JB        0.0       1.0
# JetBlue Airways  2023-12-29      Friday      N216JB        1.0       0.0
# JetBlue Airways  2023-12-31      Sunday      N952JB        0.0       1.0
#
#                 Dep_Airport         Dep_CityName DepTime_label  \
# Airline
# ...

# %%
df.groupby('Day_Of_Week').sum().sort_values(by = 'Cancelled', ascending = False)
df3 = df.groupby('Day_Of_Week').sum().sort_values(by = 'Cancelled', ascending = False)
df3
# Out:
#              Cancelled  Diverted
# Day_Of_Week
# Wednesday      15090.0    2371.0
# Sunday         14326.0    2595.0
# Monday         13159.0    2174.0
# Tuesday        12318.0    2149.0
# Friday         12154.0    2668.0
# Thursday       11313.0    2471.0
# Saturday        9576.0    2124.0

# %%
df3.plot(figsize =  (15, 5))
# Out:
# <AxesSubplot:xlabel='Day_Of_Week'>

# %%
df.groupby('Distance_type').sum().sort_values(by = 'Cancelled', ascending = False)
df4 = df.groupby('Distance_type').sum().sort_values(by = 'Cancelled', ascending = False)
df4
# Out:
#                Cancelled  Diverted
# Distance_type
# Short Haul       78865.0   13411.0
# Medium Haul       8905.0    3087.0
# Long Haul          166.0      54.0

# %%
df4.plot(kind = 'barh', figsize = (15, 5))
# Out:
# <AxesSubplot:ylabel='Distance_type'>

# %%
df.groupby('DepTime_label').sum().sort_values(by = 'Cancelled', ascending = False)
df5 = df.groupby('DepTime_label').sum().sort_values(by = 'Cancelled', ascending = False)
df5
# Out:
#                Cancelled  Diverted
# DepTime_label
# Afternoon        30479.0    7463.0
# Evening          28836.0    3276.0
# Morning          25908.0    5503.0
# Night             2713.0     310.0

# %%
df5.plot.area()
# Out:
# <AxesSubplot:xlabel='DepTime_label'>
