# %%
import pandas as pd

# %%
#obtaining the supposed website we are scraping the data from

# %%
url = 'https://en.wikipedia.org/wiki/European_Cup_and_UEFA_Champions_League_records_and_statistics'

# %%
#asked pandas to read the website

# %%
pd.read_html(url)
# Out:
# [   .mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" · ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-parser-output .hlist li:last-child::after{content:none}.
# ...

# %%
#we defined the dataframe as 'tables'

# %%
tables = pd.read_html(url)

# %%
#we found out the total number of tables on the website page

# %%
len(tables)
# Out:
# 20

# %%
#we checked the website, and we discovered we are working with the third table which is [2] in python

# %%
df = tables [2]
df
# Out:
#     Rank                 Club  Seasons  \
# 0      1          Real Madrid       55
# 1      2        Bayern Munich       41
# 2      3            Barcelona       34
# 3      4    Manchester United       30
# 4      5             Juventus       38
# 5      6            Liverpool       28
# 6      7                Milan       32
# 7      8              Benfica       43
# 8      9                Porto       38
# 9     10                 Ajax       39
# 10    11          Dynamo Kyiv       40
# 11    12              Chelsea       19
# 12    13          Inter Milan       25
# 13    14              Arsenal       22
# 14    15               Celtic       38
# 15    16    Borussia Dortmund       22
# 16    17      Atlético Madrid       19
# 17    18        PSV Eindhoven       32
# 18    19  Paris Saint-Germain       17
# 19    20           Anderlecht       34
# 20    21    Red Star Belgrade       30
# 21    22      Manchester City       14
# 22    23              Rangers       34
# ...

# %%
#we had to create a duplicate for df so as not to mess the initial data up and we named the duplicate df2

# %%
df2 = df
df2
# Out:
#     Rank                 Club  Seasons  Played    W   D    L    GF   GA    GD  \
# 0      1          Real Madrid       55     490  295  85  110  1078  537  +541
# 1      2        Bayern Munich       41     395  237  79   79   834  388  +446
# 2      3            Barcelona       34     349  203  77   69   687  357  +330
# 3      4    Manchester United       30     299  161  70   68   545  299  +246
# 4      5             Juventus       38     302  154  70   78   482  302  +180
# 5      6            Liverpool       28     249  143  50   56   475  229  +246
# 6      7                Milan       32     274  133  70   71   443  262  +181
# 7      8              Benfica       43     293  131  68   94   482  345  +137
# 8      9                Porto       38     277  126  61   90   411  313   +98
# 9     10                 Ajax       39     247  112  64   71   396  282  +114
# 10    11          Dynamo Kyiv       40     260  107  57   96   363  321   +42
# ...

# %%
#we checked the information of datas on the table

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     25 non-null     int64
#  1   Club     25 non-null     object
#  2   Seasons  25 non-null     int64
#  3   Played   25 non-null     int64
#  4   W        25 non-null     int64
#  5   D        25 non-null     int64
#  6   L        25 non-null     int64
#  7   GF       25 non-null     int64
#  8   GA       25 non-null     int64
#  9   GD       25 non-null     object
#  10  Pts      25 non-null     int64
#  11  FW       25 non-null     int64
#  12  F        25 non-null     int64
#  13  SF       25 non-null     int64
#  14  QF       25 non-null     int64
# dtypes: int64(13), object(2)
# memory usage: 3.1+ KB

# %%
#we renamed the column to make it more understandable

# %%
df2 = df2.rename(columns={'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Pld': 'Played',
                          'W':'Won',
                          'D':'Drawn',
                          'L':'Lost',
                          'GF':'Goal_For',
                          'GA':'Goal_Against',
                          'GD':'Goal_Difference',
                          'Pts':'Points',
                          'FW':'Finals_Won',
                          'F':'Finals_Played',
                          'SF':'Semi_Finals_Played',
                          'QF':'Quarter_Finals_Played'})
df2
# Out:
#     Rank                 Club  Seasons  Played  Won  Drawn  Lost  Goal_For  \
# 0      1          Real Madrid       55     490  295     85   110      1078
# 1      2        Bayern Munich       41     395  237     79    79       834
# 2      3            Barcelona       34     349  203     77    69       687
# 3      4    Manchester United       30     299  161     70    68       545
# 4      5             Juventus       38     302  154     70    78       482
# 5      6            Liverpool       28     249  143     50    56       475
# 6      7                Milan       32     274  133     70    71       443
# 7      8              Benfica       43     293  131     68    94       482
# 8      9                Porto       38     277  126     61    90       411
# 9     10                 Ajax       39     247  112     64    71       396
# 10    11          Dynamo Kyiv       40     260  107     57    96       363
# ...

# %%
#we converted the data to an excel file

# %%
df2.to_excel('clwinners.xlsx', index=False)
